# %% [markdown]
# # Implementación del Quiz

# %%
# instalación
# !pip install huggingsound
# Out:
# Requirement already satisfied: huggingsound in /root/venv/lib/python3.7/site-packages (0.1.2)
# Requirement already satisfied: transformers<5.0.0,>=4.16.2 in /root/venv/lib/python3.7/site-packages (from huggingsound) (4.18.0)
# Requirement already satisfied: librosa<0.9.0,>=0.8.1 in /root/venv/lib/python3.7/site-packages (from huggingsound) (0.8.1)
# Requirement already satisfied: torch<2.0.0,>=1.9.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from huggingsound) (1.11.0)
# Requirement already satisfied: jiwer<3.0.0,>=2.3.0 in /root/venv/lib/python3.7/site-packages (from huggingsound) (2.3.0)
# Requirement already satisfied: llvmlite<0.37.0,>=0.36.0 in /root/venv/lib/python3.7/site-packages (from huggingsound) (0.36.0)
# Requirement already satisfied: datasets<2.0.0,>=1.18.3 in /root/venv/lib/python3.7/site-packages (from huggingsound) (1.18.4)
# Requirement already satisfied: numba<0.54.0,>=0.53.1 in /root/venv/lib/python3.7/site-packages (from huggingsound) (0.53.1)
# Requirement already satisfied: numpy>=1.17 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from transformers<5.0.0,>=4.16.2->huggingsound) (1.21.6)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /root/venv/lib/python3.7/site-packages (from transformers<5.0.0,>=4.16.2->huggingsound) (0.5.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /root/venv/lib/python3.7/site-packages (from transformers<5.0.0,>=4.16.2->huggingsound) (0.12.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from transformers<5.0.0,>=4.16.2->huggingsound) (4.11.3)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from transformers<5.0.0,>=4.16.2->huggingsound) (21.3)
# Requirement already satisfied: sacremoses in /root/venv/lib/python3.7/site-packages (from transformers<5.0.0,>=4.16.2->huggingsound) (0.0.49)
# Requirement already satisfied: regex!=2019.12.17 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from transformers<5.0.0,>=4.16.2->huggingsound) (2022.3.15)
# Requirement already satisfied: requests in /shared-libs/python3.7/py/lib/python3.7/site-packages (from transformers<5.0.0,>=4.16.2->huggingsound) (2.27.1)
# Requirement already satisfied: filelock in /shared-libs/python3.7/py/lib/python3.7/site-packages (from transformers<5.0.0,>=4.16.2->huggingsound) (3.6.0)
# Requirement already satisfied: pyyaml>=5.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from transformers<5.0.0,>=4.16.2->huggingsound) (6.0)
# Requirement already satisfied: tqdm>=4.27 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from transformers<5.0.0,>=4.16.2->huggingsound) (4.64.0)
# Requirement already satisfied: joblib>=0.14 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from librosa<0.9.0,>=0.8.1->huggingsound) (1.1.0)
# Requirement already satisfied: audioread>=2.0.0 in /root/venv/lib/python3.7/site-packages (from librosa<0.9.0,>=0.8.1->huggingsound) (2.1.9)
# Requirement already satisfied: scipy>=1.0.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from librosa<0.9.0,>=0.8.1->huggingsound) (1.7.3)
# Requirement already satisfied: pooch>=1.0 in /root/venv/lib/python3.7/site-packages (from librosa<0.9.0,>=0.8.1->huggingsound) (1.6.0)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from librosa<0.9.0,>=0.8.1->huggingsound) (1.0.2)
# Requirement already satisfied: soundfile>=0.10.2 in /root/venv/lib/python3.7/site-packages (from librosa<0.9.0,>=0.8.1->huggingsound) (0.10.3.post1)
# Requirement already satisfied: resampy>=0.2.2 in /root/venv/lib/python3.7/site-packages (from librosa<0.9.0,>=0.8.1->huggingsound) (0.2.2)
# Requirement already satisfied: decorator>=3.0.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from librosa<0.9.0,>=0.8.1->huggingsound) (5.1.1)
# Requirement already satisfied: typing-extensions in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from torch<2.0.0,>=1.9.0->huggingsound) (4.2.0)
# Requirement already satisfied: python-Levenshtein==0.12.2 in /root/venv/lib/python3.7/site-packages (from jiwer<3.0.0,>=2.3.0->huggingsound) (0.12.2)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /root/venv/lib/python3.7/site-packages (from datasets<2.0.0,>=1.18.3->huggingsound) (2022.3.0)
# Requirement already satisfied: responses<0.19 in /root/venv/lib/python3.7/site-packages (from datasets<2.0.0,>=1.18.3->huggingsound) (0.18.0)
# Requirement already satisfied: aiohttp in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from datasets<2.0.0,>=1.18.3->huggingsound) (3.8.1)
# Requirement already satisfied: xxhash in /root/venv/lib/python3.7/site-packages (from datasets<2.0.0,>=1.18.3->huggingsound) (3.0.0)
# Requirement already satisfied: pyarrow!=4.0.0,>=3.0.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from datasets<2.0.0,>=1.18.3->huggingsound) (7.0.0)
# Requirement already satisfied: pandas in /shared-libs/python3.7/py/lib/python3.7/site-packages (from datasets<2.0.0,>=1.18.3->huggingsound) (1.2.5)
# Requirement already satisfied: multiprocess in /root/venv/lib/python3.7/site-packages (from datasets<2.0.0,>=1.18.3->huggingsound) (0.70.12.2)
# Requirement already satisfied: dill in /shared-libs/python3.7/py/lib/python3.7/site-packages (from datasets<2.0.0,>=1.18.3->huggingsound) (0.3.4)
# Requirement already satisfied: setuptools in /root/venv/lib/python3.7/site-packages (from numba<0.54.0,>=0.53.1->huggingsound) (47.1.0)
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->transformers<5.0.0,>=4.16.2->huggingsound) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from packaging>=20.0->transformers<5.0.0,>=4.16.2->huggingsound) (3.0.8)
# Requirement already satisfied: six in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from sacremoses->transformers<5.0.0,>=4.16.2->huggingsound) (1.16.0)
# Requirement already satisfied: click in /shared-libs/python3.7/py/lib/python3.7/site-packages (from sacremoses->transformers<5.0.0,>=4.16.2->huggingsound) (8.0.4)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from requests->transformers<5.0.0,>=4.16.2->huggingsound) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests->transformers<5.0.0,>=4.16.2->huggingsound) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests->transformers<5.0.0,>=4.16.2->huggingsound) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from requests->transformers<5.0.0,>=4.16.2->huggingsound) (2.0.12)
# Requirement already satisfied: appdirs>=1.3.0 in /root/venv/lib/python3.7/site-packages (from pooch>=1.0->librosa<0.9.0,>=0.8.1->huggingsound) (1.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa<0.9.0,>=0.8.1->huggingsound) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from soundfile>=0.10.2->librosa<0.9.0,>=0.8.1->huggingsound) (1.15.0)
# Requirement already satisfied: attrs>=17.3.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from aiohttp->datasets<2.0.0,>=1.18.3->huggingsound) (21.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from aiohttp->datasets<2.0.0,>=1.18.3->huggingsound) (1.3.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from aiohttp->datasets<2.0.0,>=1.18.3->huggingsound) (1.7.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from aiohttp->datasets<2.0.0,>=1.18.3->huggingsound) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from aiohttp->datasets<2.0.0,>=1.18.3->huggingsound) (6.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from aiohttp->datasets<2.0.0,>=1.18.3->huggingsound) (1.2.0)
# Requirement already satisfied: asynctest==0.13.0; python_version < "3.8" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from aiohttp->datasets<2.0.0,>=1.18.3->huggingsound) (0.13.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pandas->datasets<2.0.0,>=1.18.3->huggingsound) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pandas->datasets<2.0.0,>=1.18.3->huggingsound) (2022.1)
# Requirement already satisfied: pycparser in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa<0.9.0,>=0.8.1->huggingsound) (2.21)
# WARNING: You are using pip version 20.1.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
# librerías
from huggingsound import SpeechRecognitionModel

# conjunto de palabras
words = ['gato', 'escuela', 'perro', 'niño', 'casa']

# %%
# instalación
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /root/venv/lib/python3.7/site-packages (4.18.0)
# Requirement already satisfied: tqdm>=4.27 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from transformers) (4.64.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /root/venv/lib/python3.7/site-packages (from transformers) (0.5.1)
# Requirement already satisfied: filelock in /shared-libs/python3.7/py/lib/python3.7/site-packages (from transformers) (3.6.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from transformers) (4.11.3)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from transformers) (21.3)
# Requirement already satisfied: requests in /shared-libs/python3.7/py/lib/python3.7/site-packages (from transformers) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /root/venv/lib/python3.7/site-packages (from transformers) (0.12.1)
# Requirement already satisfied: numpy>=1.17 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from transformers) (1.21.6)
# Requirement already satisfied: sacremoses in /root/venv/lib/python3.7/site-packages (from transformers) (0.0.49)
# Requirement already satisfied: regex!=2019.12.17 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from transformers) (2022.3.15)
# Requirement already satisfied: pyyaml>=5.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.2.0)
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from packaging>=20.0->transformers) (3.0.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests->transformers) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from requests->transformers) (3.3)
# Requirement already satisfied: six in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from sacremoses->transformers) (1.16.0)
# Requirement already satisfied: click in /shared-libs/python3.7/py/lib/python3.7/site-packages (from sacremoses->transformers) (8.0.4)
# Requirement already satisfied: joblib in /shared-libs/python3.7/py/lib/python3.7/site-packages (from sacremoses->transformers) (1.1.0)
# WARNING: You are using pip version 20.1.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
# traducción a Nahuatl
from transformers import AutoModelForSeq2SeqLM
from tqdm.notebook import tqdm_notebook
from transformers import AutoTokenizer

model = AutoModelForSeq2SeqLM.from_pretrained('hackathon-pln-es/t5-small-spanish-nahuatl')
tokenizer = AutoTokenizer.from_pretrained('hackathon-pln-es/t5-small-spanish-nahuatl')

model.eval()
sentence = 'Mi hermano es un ajolote'
input_ids = tokenizer('translate Spanish to Nahuatl: ' + sentence, return_tensors='pt').input_ids
outputs = model.generate(input_ids)
# outputs = miak xochitl istak
outputs = tokenizer.batch_decode(outputs, skip_special_tokens=True)[0]
# Out:
# Downloading:   0%|          | 0.00/1.37k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/231M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.90k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.31M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.74k [00:00<?, ?B/s]

# %% [markdown]
# # Paso 1: conversión de texto en español a Nahuatl

# %%
# arreglo de palabras en Nahuatl
words_nahuatl = []

for i in tqdm_notebook(words):
    sentence = i
    input_ids = tokenizer('translate Spanish to Nahuatl: ' + sentence, return_tensors='pt').input_ids
    outputs = model.generate(input_ids)
    outputs = tokenizer.batch_decode(outputs, skip_special_tokens=True)[0]
    words_nahuatl.append(outputs)
    print(f'"{i}" se dice "{outputs}" en Nahuatl.')
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# "gato" se dice "mistle" en Nahuatl.
# "escuela" se dice "tlamachtiloyan" en Nahuatl.
# "perro" se dice "chichi" en Nahuatl.
# "niño" se dice "pili" en Nahuatl.
# "casa" se dice "kali" en Nahuatl.

# %% [markdown]
# # Paso 2: grabación de palabra en Nahuatl

# %%
# all imports
from IPython.display import Javascript
#from google.colab import output
from base64 import b64decode

RECORD = """
const sleep  = time => new Promise(resolve => setTimeout(resolve, time))
const b2text = blob => new Promise(resolve => {
  const reader = new FileReader()
  reader.onloadend = e => resolve(e.srcElement.result)
  reader.readAsDataURL(blob)
})
var record = time => new Promise(async resolve => {
  stream = await navigator.mediaDevices.getUserMedia({ audio: true })
  recorder = new MediaRecorder(stream)
  chunks = []
  recorder.ondataavailable = e => chunks.push(e.data)
  recorder.start()
  await sleep(time)
  recorder.onstop = async ()=>{
    blob = new Blob(chunks)
    text = await b2text(blob)
    resolve(text)
  }
  recorder.stop()
})
"""

def record(sec=3):
  display(Javascript(RECORD))
  s = output.eval_js('record(%d)' % (sec*1000))
  b = b64decode(s.split(',')[1])
  with open('audio.wav','wb') as f:
    f.write(b)
  return 'audio.wav'

# %%
#record()

# %% [markdown]
# # Paso 3: de voz en Nahuatl a texto en Nahuatl

# %%
model = SpeechRecognitionModel("tyoc213/wav2vec2-large-xlsr-nahuatl")
audio_paths = ["/content/audio.wav"]
# Out:
# 04/30/2022 17:32:13 - INFO - huggingsound.speech_recognition.model - Loading model...
# Downloading:   0%|          | 0.00/1.54k [00:00<?, ?B/s]
# /root/venv/lib/python3.7/site-packages/transformers/configuration_utils.py:359: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   "Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 "
# Downloading:   0%|          | 0.00/1.18G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/158 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/138 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/536 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/85.0 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 04/30/2022 17:32:55 - WARNING - root - bos_token <s> not in provided tokens. It will be added to the list of tokens
# 04/30/2022 17:32:55 - WARNING - root - eos_token </s> not in provided tokens. It will be added to the list of tokens

# %%
transcriptions_nah = model.transcribe(audio_paths)[0]
transcriptions_nah['transcription']
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~/venv/lib/python3.7/site-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     148     try:
# --> 149         with sf.SoundFile(path) as sf_desc:
#     150             sr_native = sf_desc.samplerate
#
# ~/venv/lib/python3.7/site-packages/soundfile.py in __init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd)
#     628                                          format, subtype, endian)
# --> 629         self._file = self._open(file, mode_int, closefd)
#     630         if set(mode).issuperset('r+') and self.seekable():
#
# ~/venv/lib/python3.7/site-packages/soundfile.py in _open(self, file, mode_int, closefd)
#    1183         _error_check(_snd.sf_error(file_ptr),
# -> 1184                      "Error opening {0!r}: ".format(self.name))
#    1185         if mode_int == _snd.SFM_WRITE:
#
# ~/venv/lib/python3.7/site-packages/soundfile.py in _error_check(err, prefix)
#    1356         err_str = _snd.sf_error_number(err)
# -> 1357         raise RuntimeError(prefix + _ffi.string(err_str).decode('utf-8', 'replace'))
#    1358
#
# RuntimeError: Error opening '/content/audio.wav': System error.
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-594044e022e2> in <module>
# ----> 1 transcriptions_nah = model.transcribe(audio_paths)[0]
#       2 transcriptions_nah['transcription']
#
# ~/venv/lib/python3.7/site-packages/huggingsound/speech_recognition/model.py in transcribe(self, paths, batch_size, decoder)
#     106         for paths_batch in tqdm(list(get_chunks(paths, batch_size))):
#     107
# --> 108             waveforms = get_waveforms(paths_batch, sampling_rate)
#     109
#     110             inputs = self.processor(waveforms, sampling_rate=sampling_rate, return_tensors="pt", padding=True, do_normalize=True)
#
# ~/venv/lib/python3.7/site-packages/huggingsound/utils.py in get_waveforms(pahts, sampling_rate)
#      50         warnings.simplefilter("ignore")
#      51         for path in pahts:
# ---> 52             waveform, sr = librosa.load(path, sr=sampling_rate)
#      53             waveforms.append(waveform)
#      54
#
# ~/venv/lib/python3.7/site-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     164         if isinstance(path, (str, pathlib.PurePath)):
#     165             warnings.warn("PySoundFile failed. Trying audioread instead.")
# --> 166             y, sr_native = __audioread_load(path, offset, duration, dtype)
#     167         else:
#     168             raise (exc)
#
# ~/venv/lib/python3.7/site-packages/librosa/core/audio.py in __audioread_load(path, offset, duration, dtype)
#     188
#     189     y = []
# --> 190     with audioread.audio_open(path) as input_file:
#     191         sr_native = input_file.samplerate
#     192         n_channels = input_file.channels
#
# ~/venv/lib/python3.7/site-packages/audioread/__init__.py in audio_open(path, backends)
#     109     for BackendClass in backends:
#     110         try:
# --> 111             return BackendClass(path)
#     112         except DecodeError:
#     113             pass
#
# ~/venv/lib/python3.7/site-packages/audioread/rawread.py in __init__(self, filename)
#      60     """
#      61     def __init__(self, filename):
# ---> 62         self._fh = open(filename, 'rb')
#      63
#      64         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/audio.wav'

# %% [markdown]
# # Paso 4: análisis de similitud

# %% [markdown]
# Emplearemos la similitud de Jaccard que está dada por:
#
# $$ \text{sim} _ {\text{jaccard}} (s_1, s_2) = \frac{\text{c}_{\text{common}}}{\text{c}_1 + \text{c}_2 - \text{c}_{\text{common}}}$$
#
# donde:
#
# - $\text{c}_{\text{common}} = $ número de bigramas en común.
#
# - $\text{c}_i = \text{len}(s_i)- 1$

# %%
def sim_jac(s1, s2):

    bigrams_s1 = []
    bigrams_s2 = []

    for i in range(len(s1) - 1):
        bigrams_s1.append(s1[i:i+2])
    
    for i in range(len(s2) - 1):
        bigrams_s2.append(s2[i:i+2])

    c_common = 0

    for i in bigrams_s1:
        if bigrams_s2.count(i) > 0:
            c_common += 1

    return c_common / ((len(s1) - 1) + (len(s2) - 1) - c_common)

# %%
# comparación entre mistle y miestleh
sim_jac('mistle', transcriptions_nah['transcription'])
# Out:
# 0.5

# %% [markdown]
# ## Ahora con modelo de español a texto y ver su similitud

# %%
from ipywebrtc import AudioRecorder, CameraStream
import torchaudio
from IPython.display import Audio


camera = CameraStream(constraints={'audio': True,'video':False})
recorder = AudioRecorder(stream=camera)
recorder
# Out:
# AudioRecorder(audio=Audio(value=b'', format='webm'), stream=CameraStream(constraints={'audio': True, 'video': …

# %%
with open('./grabaciones-webm/test.webm', 'wb') as f:
    f.write(recorder.audio.value)

# !ffmpeg -i ./grabaciones-webm/test.webm -ac 1 -f wav ./grabaciones-wav/test.wav -y -hide_banner -loglevel panic

# %%
from huggingsound import SpeechRecognitionModel

model = SpeechRecognitionModel("patrickvonplaten/wav2vec2-large-xlsr-53-spanish-with-lm")
audio_paths = ["./grabaciones-wav/test.wav"]

transcriptions_es = model.transcribe(audio_paths)[0]
# Out:
# 04/29/2022 23:25:52 - INFO - huggingsound.speech_recognition.model - Loading model...
# Downloading:   0%|          | 0.00/1.53k [00:00<?, ?B/s]
# /root/venv/lib/python3.7/site-packages/transformers/configuration_utils.py:359: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   "Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 "
# Downloading:   0%|          | 0.00/1.18G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/262 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/412 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/85.0 [00:00<?, ?B/s]
# 100%|██████████| 1/1 [00:03<00:00,  3.05s/it]

# %%
transcriptions_es['transcription']
# Out:
# 'mistley'

# %%
# comparación entre mistle y miestleh
sim_jac('mistle', transcriptions_es['transcription'])
# Out:
# 0.8333333333333334

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=17740a58-e960-4de3-bb66-1575286930f1' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
