# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting transformers==4.18.0
#   Downloading transformers-4.18.0-py3-none-any.whl (4.0 MB)
# Collecting huggingsound
#   Downloading HuggingSound-0.1.2-py3-none-any.whl (28 kB)
# Collecting ipywebrtc
#   Downloading ipywebrtc-0.6.0-py2.py3-none-any.whl (260 kB)
# Collecting ipywidgets==7.7.0
#   Downloading ipywidgets-7.7.0-py2.py3-none-any.whl (123 kB)
# Collecting torchaudio==0.11.0
#   Downloading torchaudio-0.11.0-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from transformers==4.18.0->-r ./requirements.txt (line 1)) (4.11.3)
# Requirement already satisfied: requests in /shared-libs/python3.7/py/lib/python3.7/site-packages (from transformers==4.18.0->-r ./requirements.txt (line 1)) (2.27.1)
# Requirement already satisfied: tqdm>=4.27 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from transformers==4.18.0->-r ./requirements.txt (line 1)) (4.64.0)
# Requirement already satisfied: numpy>=1.17 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from transformers==4.18.0->-r ./requirements.txt (line 1)) (1.21.6)
# Requirement already satisfied: regex!=2019.12.17 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from transformers==4.18.0->-r ./requirements.txt (line 1)) (2022.3.15)
# Requirement already satisfied: filelock in /shared-libs/python3.7/py/lib/python3.7/site-packages (from transformers==4.18.0->-r ./requirements.txt (line 1)) (3.6.0)
# Requirement already satisfied: pyyaml>=5.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from transformers==4.18.0->-r ./requirements.txt (line 1)) (6.0)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.5.1-py3-none-any.whl (77 kB)
# Collecting sacremoses
#   Downloading sacremoses-0.0.49-py3-none-any.whl (895 kB)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from transformers==4.18.0->-r ./requirements.txt (line 1)) (21.3)
# Requirement already satisfied: torch<2.0.0,>=1.9.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from huggingsound->-r ./requirements.txt (line 2)) (1.11.0)
# Collecting jiwer<3.0.0,>=2.3.0
#   Downloading jiwer-2.3.0-py3-none-any.whl (15 kB)
# Collecting llvmlite<0.37.0,>=0.36.0
#   Downloading llvmlite-0.36.0-cp37-cp37m-manylinux2010_x86_64.whl (25.3 MB)
# Collecting datasets<2.0.0,>=1.18.3
#   Downloading datasets-1.18.4-py3-none-any.whl (312 kB)
# Collecting librosa<0.9.0,>=0.8.1
#   Downloading librosa-0.8.1-py3-none-any.whl (203 kB)
# Collecting numba<0.54.0,>=0.53.1
#   Downloading numba-0.53.1-cp37-cp37m-manylinux2014_x86_64.whl (3.4 MB)
# Collecting jupyterlab-widgets>=1.0.0; python_version >= "3.6"
#   Downloading jupyterlab_widgets-1.1.0-py3-none-any.whl (245 kB)
# Requirement already satisfied: ipykernel>=4.5.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (5.5.5)
# Requirement already satisfied: traitlets>=4.3.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (4.3.3)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (7.32.0)
# Collecting widgetsnbextension~=3.6.0
#   Downloading widgetsnbextension-3.6.0-py2.py3-none-any.whl (1.6 MB)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (5.1.3)
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->transformers==4.18.0->-r ./requirements.txt (line 1)) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->transformers==4.18.0->-r ./requirements.txt (line 1)) (4.2.0)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from requests->transformers==4.18.0->-r ./requirements.txt (line 1)) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests->transformers==4.18.0->-r ./requirements.txt (line 1)) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests->transformers==4.18.0->-r ./requirements.txt (line 1)) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from requests->transformers==4.18.0->-r ./requirements.txt (line 1)) (2.0.12)
# Requirement already satisfied: six in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from sacremoses->transformers==4.18.0->-r ./requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: click in /shared-libs/python3.7/py/lib/python3.7/site-packages (from sacremoses->transformers==4.18.0->-r ./requirements.txt (line 1)) (8.0.4)
# Requirement already satisfied: joblib in /shared-libs/python3.7/py/lib/python3.7/site-packages (from sacremoses->transformers==4.18.0->-r ./requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from packaging>=20.0->transformers==4.18.0->-r ./requirements.txt (line 1)) (3.0.8)
# Collecting python-Levenshtein==0.12.2
#   Downloading python-Levenshtein-0.12.2.tar.gz (50 kB)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting xxhash
#   Downloading xxhash-3.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
# Requirement already satisfied: aiohttp in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from datasets<2.0.0,>=1.18.3->huggingsound->-r ./requirements.txt (line 2)) (3.8.1)
# Requirement already satisfied: pyarrow!=4.0.0,>=3.0.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from datasets<2.0.0,>=1.18.3->huggingsound->-r ./requirements.txt (line 2)) (7.0.0)
# Collecting multiprocess
#   Downloading multiprocess-0.70.12.2-py37-none-any.whl (112 kB)
# Requirement already satisfied: pandas in /shared-libs/python3.7/py/lib/python3.7/site-packages (from datasets<2.0.0,>=1.18.3->huggingsound->-r ./requirements.txt (line 2)) (1.2.5)
# Requirement already satisfied: dill in /shared-libs/python3.7/py/lib/python3.7/site-packages (from datasets<2.0.0,>=1.18.3->huggingsound->-r ./requirements.txt (line 2)) (0.3.4)
# Collecting fsspec[http]>=2021.05.0
#   Downloading fsspec-2022.3.0-py3-none-any.whl (136 kB)
# Collecting audioread>=2.0.0
#   Downloading audioread-2.1.9.tar.gz (377 kB)
# Collecting soundfile>=0.10.2
#   Downloading SoundFile-0.10.3.post1-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: scipy>=1.0.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from librosa<0.9.0,>=0.8.1->huggingsound->-r ./requirements.txt (line 2)) (1.7.3)
# Collecting resampy>=0.2.2
#   Downloading resampy-0.2.2.tar.gz (323 kB)
# Requirement already satisfied: decorator>=3.0.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from librosa<0.9.0,>=0.8.1->huggingsound->-r ./requirements.txt (line 2)) (5.1.1)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from librosa<0.9.0,>=0.8.1->huggingsound->-r ./requirements.txt (line 2)) (1.0.2)
# Collecting pooch>=1.0
#   Downloading pooch-1.6.0-py3-none-any.whl (56 kB)
# Requirement already satisfied: setuptools in /root/venv/lib/python3.7/site-packages (from numba<0.54.0,>=0.53.1->huggingsound->-r ./requirements.txt (line 2)) (47.1.0)
# Requirement already satisfied: jupyter-client in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (6.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (3.0.29)
# Requirement already satisfied: pickleshare in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (0.7.5)
# Requirement already satisfied: pygments in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (2.11.2)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (4.8.0)
# Requirement already satisfied: matplotlib-inline in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (0.1.3)
# Requirement already satisfied: backcall in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (0.17.2)
# Requirement already satisfied: notebook>=4.4.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (6.3.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (3.2.0)
# Requirement already satisfied: jupyter-core in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (4.7.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from aiohttp->datasets<2.0.0,>=1.18.3->huggingsound->-r ./requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from aiohttp->datasets<2.0.0,>=1.18.3->huggingsound->-r ./requirements.txt (line 2)) (21.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from aiohttp->datasets<2.0.0,>=1.18.3->huggingsound->-r ./requirements.txt (line 2)) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from aiohttp->datasets<2.0.0,>=1.18.3->huggingsound->-r ./requirements.txt (line 2)) (1.7.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from aiohttp->datasets<2.0.0,>=1.18.3->huggingsound->-r ./requirements.txt (line 2)) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from aiohttp->datasets<2.0.0,>=1.18.3->huggingsound->-r ./requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: asynctest==0.13.0; python_version < "3.8" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from aiohttp->datasets<2.0.0,>=1.18.3->huggingsound->-r ./requirements.txt (line 2)) (0.13.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pandas->datasets<2.0.0,>=1.18.3->huggingsound->-r ./requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pandas->datasets<2.0.0,>=1.18.3->huggingsound->-r ./requirements.txt (line 2)) (2022.1)
# Requirement already satisfied: cffi>=1.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from soundfile>=0.10.2->librosa<0.9.0,>=0.8.1->huggingsound->-r ./requirements.txt (line 2)) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa<0.9.0,>=0.8.1->huggingsound->-r ./requirements.txt (line 2)) (3.1.0)
# Collecting appdirs>=1.3.0
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: pyzmq>=13 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (22.3.0)
# Requirement already satisfied: wcwidth in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pexpect>4.3; sys_platform != "win32"->ipython>=4.0.0; python_version >= "3.3"->ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jedi>=0.16->ipython>=4.0.0; python_version >= "3.3"->ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (0.7.1)
# Requirement already satisfied: argon2-cffi in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (21.3.0)
# Requirement already satisfied: jinja2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (2.11.3)
# Requirement already satisfied: prometheus-client in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (0.14.1)
# Requirement already satisfied: terminado>=0.8.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (0.13.3)
# Requirement already satisfied: nbconvert==6.0.7 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (6.0.7)
# Requirement already satisfied: Send2Trash>=1.5.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (1.8.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (0.18.1)
# Requirement already satisfied: pycparser in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa<0.9.0,>=0.8.1->huggingsound->-r ./requirements.txt (line 2)) (2.21)
# Requirement already satisfied: argon2-cffi-bindings in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (21.2.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (2.0.1)
# Requirement already satisfied: bleach in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (5.0.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (0.8.4)
# Requirement already satisfied: testpath in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (0.6.0)
# Requirement already satisfied: defusedxml in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (0.2.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (0.5.9)
# Requirement already satisfied: entrypoints>=0.2.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (0.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (1.5.0)
# Requirement already satisfied: webencodings in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from bleach->nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (0.5.1)
# Requirement already satisfied: nest-asyncio in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.0->-r ./requirements.txt (line 4)) (1.5.5)
# Building wheels for collected packages: python-Levenshtein, audioread, resampy
#   Building wheel for python-Levenshtein (setup.py): started
#   Building wheel for python-Levenshtein (setup.py): finished with status 'done'
#   Created wheel for python-Levenshtein: filename=python_Levenshtein-0.12.2-cp37-cp37m-linux_x86_64.whl size=83252 sha256=05ddbc144a0213cc79b2e5e3dab8f67dd6c8e7a2793e9d2329069b3a41ff3f3f
#   Stored in directory: /root/.cache/pip/wheels/05/5f/ca/7c4367734892581bb5ff896f15027a932c551080b2abd3e00d
#   Building wheel for audioread (setup.py): started
#   Building wheel for audioread (setup.py): finished with status 'done'
#   Created wheel for audioread: filename=audioread-2.1.9-py3-none-any.whl size=23143 sha256=7e6c2a63aa2b0bd2e019b391179f0421b8f646be25a152b500e40648fe6d6aa2
#   Stored in directory: /root/.cache/pip/wheels/ba/7b/eb/213741ccc0678f63e346ab8dff10495995ca3f426af87b8d88
#   Building wheel for resampy (setup.py): started
#   Building wheel for resampy (setup.py): finished with status 'done'
#   Created wheel for resampy: filename=resampy-0.2.2-py3-none-any.whl size=320719 sha256=9a5259e05c46ca75f6ba008e622892f30bca3983326eb7c99ff0b10ef6d13982
#   Stored in directory: /root/.cache/pip/wheels/a0/18/0a/8ad18a597d8333a142c9789338a96a6208f1198d290ece356c
# Successfully built python-Levenshtein audioread resampy
# Installing collected packages: tokenizers, huggingface-hub, sacremoses, transformers, python-Levenshtein, jiwer, llvmlite, responses, xxhash, multiprocess, fsspec, datasets, audioread, soundfile, numba, resampy, appdirs, pooch, librosa, huggingsound, ipywebrtc, jupyterlab-widgets, widgetsnbextension, ipywidgets, torchaudio
# Successfully installed appdirs-1.4.4 audioread-2.1.9 datasets-1.18.4 fsspec-2022.3.0 huggingface-hub-0.5.1 huggingsound-0.1.2 ipywebrtc-0.6.0 ipywidgets-7.7.0 jiwer-2.3.0 jupyterlab-widgets-1.1.0 librosa-0.8.1 llvmlite-0.36.0 multiprocess-0.70.12.2 numba-0.53.1 pooch-1.6.0 python-Levenshtein-0.12.2 resampy-0.2.2 responses-0.18.0 sacremoses-0.0.49 soundfile-0.10.3.post1 tokenizers-0.12.1 torchaudio-0.11.0 transformers-4.18.0 widgetsnbextension-3.6.0 xxhash-3.0.0
# WARNING: You are using pip version 20.1.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=17740a58-e960-4de3-bb66-1575286930f1' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
